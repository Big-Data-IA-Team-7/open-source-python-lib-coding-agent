# %%
import os
from pathlib import Path
import shutil

import git
import magika
import requests

m = magika.Magika()

# %%
repo_url = "https://github.com/apache/airflow.git"

# %%
local_dir = "Airflow_docs"

# %%
repo_dir='./airflow_docs'

# %%
from git import Repo

# %%
repo = Repo.clone_from(repo_url, local_dir)

# %%
def clone_repo(repo_url, repo_dir):
    """Clone a GitHub repository."""

    if os.path.exists(repo_dir):
        shutil.rmtree(repo_dir)
    os.makedirs(repo_dir)
    git.Repo.clone_from(repo_url, repo_dir)

# %%
def extract_code(repo_dir):
    """Create an index, extract content of code/text files."""

    code_index = []
    code_text = ""
    for root, _, files in os.walk(repo_dir):
        for file in files:
            file_path = os.path.join(root, file)
            relative_path = os.path.relpath(file_path, repo_dir)
            code_index.append(relative_path)

            file_type = m.identify_path(Path(file_path))
            if file_type.output.group in ("text", "code"):
                try:
                    with open(file_path) as f:
                        code_text += f"----- File: {relative_path} -----\n"
                        code_text += f.read()
                        code_text += "\n-------------------------\n"
                except Exception:
                    pass

    return code_index, code_text

# %%
clone_repo(repo_url, repo_dir)

# %%
code_index, code_text = extract_code(repo_dir)

# %%
code_index
# Out:
# ['.asf.yaml',
#  '.git-blame-ignore-revs',
#  '.codespellignorelines',
#  'CODE_OF_CONDUCT.md',
#  'INTHEWILD.md',
#  'codecov.yml',
#  'RELEASE_NOTES.rst',
#  'INSTALL',
#  'LICENSE',
#  'CONTRIBUTING.rst',
#  '.pre-commit-config.yaml',
#  '.hadolint.yaml',
#  'Dockerfile',
#  'pyproject.toml',
#  'ISSUE_TRIAGE_PROCESS.rst',
#  '.readthedocs.yml',
#  '.editorconfig',
#  'NOTICE',
#  'README.md',
#  'doap_airflow.rdf',
#  '.bash_completion',
#  '.dockerignore',
#  'hatch_build.py',
#  '.gitignore',
#  'prod_image_installed_providers.txt',
#  '.gitattributes',
#  'BREEZE.rst',
#  'COMMITTERS.rst',
#  '.gitpod.yml',
#  '.mailmap',
#  'yamllint-config.yml',
#  '.markdownlint.yml',
#  'Dockerfile.ci',
#  '.rat-excludes',
#  'PROVIDERS.rst',
#  '.cherry_picker.toml',
#  'generated/dependency_depth.json',
#  'generated/README.md',
#  'generated/provider_dependencies.json',
#  'generated/devel_deps.txt',
#  'generated/PYPI_README.md',
#  'generated/provider_metadata.json',
#  'generated/dep_tree.txt',
#  'docker_tests/test_docker_compose_quick_start.py',
#  'docker_tests/conftest.py',
#  'docker_tests/docker_utils.py',
#  'docker_tests/requirements.txt',
#  'docker_tests/pyproject.toml',
#  'docker_tests/constants.py',
#  'docker_tests/test_examples_of_prod_image_building.py',
#  'docker_tests/__init__.py',
#  'docker_tests/command_utils.py',
#  'docker_tests/test_ci_image.py',
#  'docker_tests/test_prod_image.py',
#  'docker-context-files/.README.md',
#  'clients/README.md',
#  'clients/python/INSTALL',
#  'clients/python/LICENSE',
#  'clients/python/CHANGELOG.md',
#  'clients/python/.openapi-generator-ignore',
#  'clients/python/pyproject.toml',
#  'clients/python/test_python_client.py',
#  'clients/python/NOTICE',
#  'clients/python/README.md',
#  'clients/python/.gitignore',
#  'clients/python/version.txt',
#  'tests_common/pyproject.toml',
#  'tests_common/__init__.py',
#  'tests_common/pytest_plugin.py',
#  'tests_common/test_utils/sftp_system_helpers.py',
#  'tests_common/test_utils/db.py',
#  'tests_common/test_utils/mock_plugins.py',
#  'tests_common/test_utils/timetables.py',
#  'tests_common/test_utils/terraform.py',
#  'tests_common/test_utils/get_all_tests.py',
#  'tests_common/test_utils/config.py',
#  'tests_common/test_utils/mock_security_manager.py',
#  'tests_common/test_utils/compat.py',
#  'tests_common/test_utils/logging_command_executor.py',
#  'tests_common/test_utils/log_handlers.py',
#  'tests_common/test_utils/mock_operators.py',
#  'tests_common/test_utils/remote_user_api_auth_backend.py',
#  'tests_common/test_utils/__init__.py',
#  'tests_common/test_utils/system_tests_class.py',
#  'tests_common/test_utils/README.md',
#  'tests_common/test_utils/providers.py',
#  'tests_common/test_utils/reset_warning_registry.py',
#  'tests_common/test_utils/www.py',
#  'tests_common/test_utils/hdfs_utils.py',
#  'tests_common/test_utils/permissions.py',
#  'tests_common/test_utils/fake_datetime.py',
#  'tests_common/test_utils/watcher.py',
#  'tests_common/test_utils/system_tests.py',
#  'tests_common/test_utils/api_connexion_utils.py',
#  'tests_common/test_utils/asserts.py',
#  'tests_common/test_utils/mock_executor.py',
#  'tests_common/test_utils/mapping.py',
#  'tests_common/test_utils/gcp_system_helpers.py',
#  'tests_common/test_utils/azure_system_helpers.py',
#  'tests_common/test_utils/salesforce_system_helpers.py',
#  'tests_common/test_utils/decorators.py',
#  'tests_common/test_utils/operators/__init__.py',
#  'tests_common/test_utils/operators/postgres_local_executor.cfg',
#  'tests_common/test_utils/perf/__init__.py',
#  'tests_common/test_utils/perf/perf_kit/memory.py',
#  'tests_common/test_utils/perf/perf_kit/__init__.py',
#  'tests_common/test_utils/perf/perf_kit/sqlalchemy.py',
#  'tests_common/test_utils/perf/perf_kit/python.py',
#  'tests_common/test_utils/perf/perf_kit/repeat_and_time.py',
#  'tests_common/_internals/forbidden_warnings.py',
#  'tests_common/_internals/__init__.py',
#  'tests_common/_internals/capture_warnings.py',
#  'helm_tests/__init__.py',
#  'helm_tests/security/test_rbac_pod_log_reader.py',
#  'helm_tests/security/test_metadata_connection_secret.py',
#  'helm_tests/security/test_rbac.py',
#  'helm_tests/security/__init__.py',
#  'helm_tests/security/test_scc_rolebinding.py',
#  'helm_tests/security/test_extra_configmaps_secrets.py',
#  'helm_tests/security/test_security_context.py',
#  'helm_tests/security/test_result_backend_connection_secret.py',
#  'helm_tests/security/test_elasticsearch_secret.py',
#  'helm_tests/security/test_kerberos.py',
#  'helm_tests/airflow_aux/test_create_user_job.py',
#  'helm_tests/airflow_aux/test_configmap.py',
#  'helm_tests/airflow_aux/test_migrate_database_job.py',
#  'helm_tests/airflow_aux/test_container_lifecycle.py',
#  'helm_tests/airflow_aux/__init__.py',
#  'helm_tests/airflow_aux/test_pod_template_file.py',
#  'helm_tests/airflow_aux/test_annotations.py',
#  'helm_tests/airflow_aux/test_logs_persistent_volume_claim.py',
#  'helm_tests/airflow_aux/test_extra_env_env_from.py',
#  'helm_tests/airflow_aux/test_celery_kubernetes_executor.py',
#  'helm_tests/airflow_aux/test_cleanup_pods.py',
#  'helm_tests/airflow_aux/test_basic_helm_chart.py',
#  'helm_tests/airflow_aux/test_pod_launcher_role.py',
#  'helm_tests/airflow_aux/test_chart_quality.py',
#  'helm_tests/airflow_aux/test_airflow_common.py',
#  'helm_tests/other/test_redis.py',
#  'helm_tests/other/test_limit_ranges.py',
#  'helm_tests/other/test_git_sync_webserver.py',
#  'helm_tests/other/test_git_sync_triggerer.py',
#  'helm_tests/other/test_statsd.py',
#  'helm_tests/other/test_resource_quota.py',
#  'helm_tests/other/__init__.py',
#  'helm_tests/other/test_flower.py',
#  'helm_tests/other/test_pgbouncer.py',
#  'helm_tests/other/test_git_sync_worker.py',
#  'helm_tests/other/test_dags_persistent_volume_claim.py',
#  'helm_tests/other/test_keda.py',
#  'helm_tests/other/test_git_ssh_key_secret.py',
#  'helm_tests/other/test_git_sync_scheduler.py',
#  'helm_tests/other/test_pdb_pgbouncer.py',
#  'helm_tests/other/test_hpa.py',
#  'helm_tests/webserver/test_ingress_flower.py',
#  'helm_tests/webserver/test_pdb_webserver.py',
#  'helm_tests/webserver/test_ingress_web.py',
#  'helm_tests/webserver/__init__.py',
#  'helm_tests/webserver/test_hpa_webserver.py',
#  'helm_tests/webserver/test_webserver.py',
#  'helm_tests/airflow_core/test_rpc_server.py',
#  'helm_tests/airflow_core/__init__.py',
#  'helm_tests/airflow_core/test_env.py',
#  'helm_tests/airflow_core/test_scheduler.py',
#  'helm_tests/airflow_core/test_worker.py',
#  'helm_tests/airflow_core/test_triggerer.py',
#  'helm_tests/airflow_core/test_dag_processor.py',
#  'helm_tests/airflow_core/test_pdb_scheduler.py',
#  'empty/.gitignore',
#  'constraints/README.md',
#  'newsfragments/41776.significant.rst',
#  'newsfragments/41496.significant.rst',
#  'newsfragments/41368.significant.rst',
#  'newsfragments/43902.significant.rst',
#  'newsfragments/42660.significant.rst',
#  'newsfragments/41390.significant.rst',
#  'newsfragments/41975.significant.rst',
#  'newsfragments/41453.significant.rst',
#  'newsfragments/42137.significant.rst',
#  'newsfragments/41808.significant.rst',
#  'newsfragments/41367.significant.rst',
#  'newsfragments/41779.significant.rst',
#  'newsfragments/42739.significant.rst',
#  'newsfragments/42129.significant.rst',
#  'newsfragments/41964.significant.rst',
#  'newsfragments/41739.significant.rst',
#  'newsfragments/42343.significant.rst',
#  'newsfragments/42042.significant.rst',
#  'newsfragments/41096.significant.rst',
#  'newsfragments/42054.significant.rst',
#  'newsfragments/42126.significant.rst',
#  'newsfragments/42088.significant.rst',
#  'newsfragments/41736.significant.rst',
#  'newsfragments/42776.significant.rst',
#  'newsfragments/40936.bugfix.rst',
#  'newsfragments/41420.significant.rst',
#  'newsfragments/43562.significant.rst',
#  'newsfragments/41552.significant.rst',
#  'newsfragments/40931.significant.rst',
#  'newsfragments/43943.significant.rst',
#  'newsfragments/42280.significant.rst',
#  'newsfragments/43533.significant.rst',
#  'newsfragments/41737.significant.rst',
#  'newsfragments/41910.significant.rst',
#  'newsfragments/41579.significant.rst',
#  'newsfragments/41642.significant.rst',
#  'newsfragments/41539.significant.rst',
#  'newsfragments/42579.significant.rst',
#  'newsfragments/42436.significant.rst',
#  'newsfragments/41391.significant.rst',
#  'newsfragments/41520.significant.rst',
#  'newsfragments/44080.significant.rst',
#  'newsfragments/43611.significant.rst',
#  'newsfragments/41780.significant.rst',
#  'newsfragments/43073.significant.rst',
#  'newsfragments/41761.significant.rst',
#  'newsfragments/42060.significant.rst',
#  'newsfragments/41366.significant.rst',
#  'newsfragments/41778.significant.rst',
#  'newsfragments/41857.significant.rst',
#  'newsfragments/42783.improvement.rst',
#  'newsfragments/43915.significant.rst',
#  'newsfragments/43183.significant.rst',
#  'newsfragments/42404.significant.rst',
#  'newsfragments/41550.significant.rst',
#  'newsfragments/41533.significant.rst',
#  'newsfragments/43490.significant.rst',
#  'newsfragments/41708.significant.rst',
#  'newsfragments/41735.significant.rst',
#  'newsfragments/41434.significant.rst',
#  'newsfragments/42640.significant.rst',
#  'newsfragments/41429.improvement.rst',
#  'newsfragments/43291.significant.rst',
#  'newsfragments/41348.significant.rst',
#  'newsfragments/44300.bugfix.rst',
#  'newsfragments/41663.significant.rst',
#  'newsfragments/41394.significant.rst',
#  'newsfragments/41393.significant.rst',
#  'newsfragments/43568.significant.rst',
#  'newsfragments/42647.significant.rst',
#  'newsfragments/41748.significant.rst',
#  'newsfragments/42285.significant.rst',
#  'newsfragments/43067.significant.rst',
#  'newsfragments/41693.significant.rst',
#  'newsfragments/42439.bugfix.rst',
#  'newsfragments/41635.significant.rst',
#  'newsfragments/24842.significant.rst',
#  'newsfragments/43679.misc.rst',
#  'newsfragments/43612.significant.rst',
#  'newsfragments/41733.significant.rst',
#  'newsfragments/config.toml',
#  'newsfragments/aip-72.significant.rst',
#  'newsfragments/41774.significant.rst',
#  'newsfragments/40029.significant.rst',
#  'newsfragments/42548.significant.rst',
#  'newsfragments/43368.significant.rst',
#  'newsfragments/41609.significant.rst',
#  'newsfragments/41762.significant.rst',
#  'newsfragments/42343.feature.rst',
#  'newsfragments/43975.significant.rst',
#  'newsfragments/43102.significant.rst',
#  'newsfragments/41784.significant.rst',
#  'newsfragments/43096.significant.rst',
#  'newsfragments/41758.significant.rst',
#  'newsfragments/41440.significant.rst',
#  'newsfragments/42023.significant.rst',
#  'newsfragments/43289.significant.rst',
#  'newsfragments/42953.significant.rst',
#  'newsfragments/43530.significant.rst',
#  'newsfragments/41395.significant.rst',
#  'newsfragments/42658.significant.rst',
#  'newsfragments/42100.significant.rst',
#  'providers/pyproject.toml',
#  'providers/__init__.py',
#  'providers/.gitignore',
#  'providers/tests/conftest.py',
#  'providers/tests/__init__.py',
#  'providers/tests/deprecations_ignore.yml',
#  'providers/tests/neo4j/__init__.py',
#  'providers/tests/neo4j/operators/__init__.py',
#  'providers/tests/neo4j/operators/test_neo4j.py',
#  'providers/tests/neo4j/hooks/__init__.py',
#  'providers/tests/neo4j/hooks/test_neo4j.py',
#  'providers/tests/cohere/__init__.py',
#  'providers/tests/cohere/operators/__init__.py',
#  'providers/tests/cohere/operators/test_embedding.py',
#  'providers/tests/cohere/hooks/test_cohere.py',
#  'providers/tests/cohere/hooks/__init__.py',
#  'providers/tests/ftp/__init__.py',
#  'providers/tests/ftp/sensors/__init__.py',
#  'providers/tests/ftp/sensors/test_ftp.py',
#  'providers/tests/ftp/operators/__init__.py',
#  'providers/tests/ftp/operators/test_ftp.py',
#  'providers/tests/ftp/hooks/__init__.py',
#  'providers/tests/ftp/hooks/test_ftp.py',
#  'providers/tests/presto/__init__.py',
#  'providers/tests/presto/transfers/__init__.py',
#  'providers/tests/presto/transfers/test_gcs_to_presto.py',
#  'providers/tests/presto/hooks/test_presto.py',
#  'providers/tests/presto/hooks/__init__.py',
#  'providers/tests/papermill/__init__.py',
#  'providers/tests/papermill/operators/__init__.py',
#  'providers/tests/papermill/operators/test_papermill.py',
#  'providers/tests/papermill/hooks/__init__.py',
#  'providers/tests/papermill/hooks/test_kernel.py',
#  'providers/tests/docker/conftest.py',
#  'providers/tests/docker/test_exceptions.py',
#  'providers/tests/docker/__init__.py',
#  'providers/tests/docker/operators/__init__.py',
#  'providers/tests/docker/operators/test_docker_swarm.py',
#  'providers/tests/docker/operators/test_docker.py',
#  'providers/tests/docker/decorators/__init__.py',
#  'providers/tests/docker/decorators/test_docker.py',
#  'providers/tests/docker/hooks/__init__.py',
#  'providers/tests/docker/hooks/test_docker.py',
#  'providers/tests/imap/__init__.py',
#  'providers/tests/imap/sensors/__init__.py',
#  'providers/tests/imap/sensors/test_imap_attachment.py',
#  'providers/tests/imap/hooks/__init__.py',
#  'providers/tests/imap/hooks/test_imap.py',
#  'providers/tests/discord/__init__.py',
#  'providers/tests/discord/operators/test_discord_webhook.py',
#  'providers/tests/discord/operators/__init__.py',
#  'providers/tests/discord/hooks/test_discord_webhook.py',
#  'providers/tests/discord/hooks/__init__.py',
#  'providers/tests/discord/notifications/__init__.py',
#  'providers/tests/discord/notifications/test_discord.py',
#  'providers/tests/tableau/__init__.py',
#  'providers/tests/tableau/sensors/test_tableau.py',
#  'providers/tests/tableau/sensors/__init__.py',
#  'providers/tests/tableau/operators/test_tableau.py',
#  'providers/tests/tableau/operators/__init__.py',
#  'providers/tests/tableau/hooks/test_tableau.py',
#  'providers/tests/tableau/hooks/__init__.py',
#  'providers/tests/amazon/conftest.py',
#  'providers/tests/amazon/__init__.py',
#  'providers/tests/amazon/aws/__init__.py',
#  'providers/tests/amazon/aws/.gitignore',
#  'providers/tests/amazon/aws/config_templates/args.json',
#  'providers/tests/amazon/aws/config_templates/__init__.py',
#  'providers/tests/amazon/aws/config_templates/steps.json',
#  'providers/tests/amazon/aws/config_templates/job.j2.json',
#  'providers/tests/amazon/aws/config_templates/steps.j2.json',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_training.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_automl.py',
#  'providers/tests/amazon/aws/sensors/test_kinesis_analytics.py',
#  'providers/tests/amazon/aws/sensors/test_emr_serverless_job.py',
#  'providers/tests/amazon/aws/sensors/test_lambda_function.py',
#  'providers/tests/amazon/aws/sensors/test_athena.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_pipeline.py',
#  'providers/tests/amazon/aws/sensors/test_rds.py',
#  'providers/tests/amazon/aws/sensors/test_dms.py',
#  'providers/tests/amazon/aws/sensors/test_dynamodb.py',
#  'providers/tests/amazon/aws/sensors/test_glue_crawler.py',
#  'providers/tests/amazon/aws/sensors/__init__.py',
#  'providers/tests/amazon/aws/sensors/test_glacier.py',
#  'providers/tests/amazon/aws/sensors/test_emr_notebook_execution.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_tuning.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_endpoint.py',
#  'providers/tests/amazon/aws/sensors/test_opensearch_serverless.py',
#  'providers/tests/amazon/aws/sensors/test_sqs.py',
#  'providers/tests/amazon/aws/sensors/test_eks.py',
#  'providers/tests/amazon/aws/sensors/test_cloud_formation.py',
#  'providers/tests/amazon/aws/sensors/test_glue_catalog_partition.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_processing.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_base.py',
#  'providers/tests/amazon/aws/sensors/test_base_aws.py',
#  'providers/tests/amazon/aws/sensors/test_quicksight.py',
#  'providers/tests/amazon/aws/sensors/test_step_function.py',
#  'providers/tests/amazon/aws/sensors/test_emr_base.py',
#  'providers/tests/amazon/aws/sensors/test_comprehend.py',
#  'providers/tests/amazon/aws/sensors/test_ecs.py',
#  'providers/tests/amazon/aws/sensors/test_emr_serverless_application.py',
#  'providers/tests/amazon/aws/sensors/test_glue.py',
#  'providers/tests/amazon/aws/sensors/test_glue_data_quality.py',
#  'providers/tests/amazon/aws/sensors/test_emr_step.py',
#  'providers/tests/amazon/aws/sensors/test_bedrock.py',
#  'providers/tests/amazon/aws/sensors/test_batch.py',
#  'providers/tests/amazon/aws/sensors/test_ec2.py',
#  'providers/tests/amazon/aws/sensors/test_redshift_cluster.py',
#  'providers/tests/amazon/aws/sensors/test_sagemaker_transform.py',
#  'providers/tests/amazon/aws/sensors/test_emr_containers.py',
#  'providers/tests/amazon/aws/sensors/test_s3.py',
#  'providers/tests/amazon/aws/sensors/test_emr_job_flow.py',
#  'providers/tests/amazon/aws/operators/test_emr_modify_cluster.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_training.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_model.py',
#  'providers/tests/amazon/aws/operators/test_kinesis_analytics.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_notebook.py',
#  'providers/tests/amazon/aws/operators/test_lambda_function.py',
#  'providers/tests/amazon/aws/operators/test_athena.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_pipeline.py',
#  'providers/tests/amazon/aws/operators/test_glue_databrew.py',
#  'providers/tests/amazon/aws/operators/test_rds.py',
#  'providers/tests/amazon/aws/operators/test_dms.py',
#  'providers/tests/amazon/aws/operators/test_glue_crawler.py',
#  'providers/tests/amazon/aws/operators/test_emr_add_steps.py',
#  'providers/tests/amazon/aws/operators/__init__.py',
#  'providers/tests/amazon/aws/operators/test_glacier.py',
#  'providers/tests/amazon/aws/operators/test_emr_notebook_execution.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_tuning.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_endpoint.py',
#  'providers/tests/amazon/aws/operators/test_sqs.py',
#  'providers/tests/amazon/aws/operators/test_eks.py',
#  'providers/tests/amazon/aws/operators/test_cloud_formation.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_processing.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_base.py',
#  'providers/tests/amazon/aws/operators/athena_metadata.json',
#  'providers/tests/amazon/aws/operators/test_base_aws.py',
#  'providers/tests/amazon/aws/operators/test_emr_create_job_flow.py',
#  'providers/tests/amazon/aws/operators/test_quicksight.py',
#  'providers/tests/amazon/aws/operators/test_step_function.py',
#  'providers/tests/amazon/aws/operators/test_redshift_sql.py',
#  'providers/tests/amazon/aws/operators/test_comprehend.py',
#  'providers/tests/amazon/aws/operators/test_ecs.py',
#  'providers/tests/amazon/aws/operators/test_sns.py',
#  'providers/tests/amazon/aws/operators/test_emr_serverless.py',
#  'providers/tests/amazon/aws/operators/test_glue.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_endpoint_config.py',
#  'providers/tests/amazon/aws/operators/test_bedrock.py',
#  'providers/tests/amazon/aws/operators/test_eventbridge.py',
#  'providers/tests/amazon/aws/operators/test_neptune.py',
#  'providers/tests/amazon/aws/operators/test_appflow.py',
#  'providers/tests/amazon/aws/operators/test_batch.py',
#  'providers/tests/amazon/aws/operators/test_ec2.py',
#  'providers/tests/amazon/aws/operators/test_redshift_cluster.py',
#  'providers/tests/amazon/aws/operators/test_redshift_data.py',
#  'providers/tests/amazon/aws/operators/test_sagemaker_transform.py',
#  'providers/tests/amazon/aws/operators/test_emr_containers.py',
#  'providers/tests/amazon/aws/operators/test_datasync.py',
#  'providers/tests/amazon/aws/operators/test_emr_terminate_job_flow.py',
#  'providers/tests/amazon/aws/operators/test_s3.py',
#  'providers/tests/amazon/aws/triggers/test_sagemaker.py',
#  'providers/tests/amazon/aws/triggers/test_kinesis_analytics.py',
#  'providers/tests/amazon/aws/triggers/test_lambda_function.py',
#  'providers/tests/amazon/aws/triggers/test_athena.py',
#  'providers/tests/amazon/aws/triggers/test_glue_databrew.py',
#  'providers/tests/amazon/aws/triggers/test_rds.py',
#  'providers/tests/amazon/aws/triggers/test_glue_crawler.py',
#  'providers/tests/amazon/aws/triggers/__init__.py',
#  'providers/tests/amazon/aws/triggers/test_emr.py',
#  'providers/tests/amazon/aws/triggers/test_opensearch_serverless.py',
#  'providers/tests/amazon/aws/triggers/test_sqs.py',
#  'providers/tests/amazon/aws/triggers/test_eks.py',
#  'providers/tests/amazon/aws/triggers/test_comprehend.py',
#  'providers/tests/amazon/aws/triggers/test_ecs.py',
#  'providers/tests/amazon/aws/triggers/test_glue.py',
#  'providers/tests/amazon/aws/triggers/test_bedrock.py',
#  'providers/tests/amazon/aws/triggers/test_neptune.py',
#  'providers/tests/amazon/aws/triggers/test_serialization.py',
#  'providers/tests/amazon/aws/triggers/test_batch.py',
#  'providers/tests/amazon/aws/triggers/test_base.py',
#  'providers/tests/amazon/aws/triggers/test_ec2.py',
#  'providers/tests/amazon/aws/triggers/test_redshift_cluster.py',
#  'providers/tests/amazon/aws/triggers/test_redshift_data.py',
#  'providers/tests/amazon/aws/triggers/test_s3.py',
#  'providers/tests/amazon/aws/secrets/__init__.py',
#  'providers/tests/amazon/aws/secrets/test_secrets_manager.py',
#  'providers/tests/amazon/aws/secrets/test_systems_manager.py',
#  'providers/tests/amazon/aws/utils/test_identifiers.py',
#  'providers/tests/amazon/aws/utils/test_utils.py',
#  'providers/tests/amazon/aws/utils/test_tags.py',
#  'providers/tests/amazon/aws/utils/test_redshift.py',
#  'providers/tests/amazon/aws/utils/test_template_fields.py',
#  'providers/tests/amazon/aws/utils/__init__.py',
#  'providers/tests/amazon/aws/utils/test_task_log_fetcher.py',
#  'providers/tests/amazon/aws/utils/test_sqs.py',
#  'providers/tests/amazon/aws/utils/test_connection_wrapper.py',
#  'providers/tests/amazon/aws/utils/test_mixins.py',
#  'providers/tests/amazon/aws/utils/test_emailer.py',
#  'providers/tests/amazon/aws/utils/eks_test_utils.py',
#  'providers/tests/amazon/aws/utils/test_suppress.py',
#  'providers/tests/amazon/aws/utils/test_eks_get_token.py',
#  'providers/tests/amazon/aws/utils/test_openlineage.py',
#  'providers/tests/amazon/aws/utils/test_waiter_with_logging.py',
#  'providers/tests/amazon/aws/utils/test_waiter.py',
#  'providers/tests/amazon/aws/utils/eks_test_constants.py',
#  'providers/tests/amazon/aws/waiters/test_kinesis_analytics.py',
#  'providers/tests/amazon/aws/waiters/test_glue_databrew.py',
#  'providers/tests/amazon/aws/waiters/__init__.py',
#  'providers/tests/amazon/aws/waiters/test.json',
#  'providers/tests/amazon/aws/waiters/test_emr.py',
#  'providers/tests/amazon/aws/waiters/test_opensearch_serverless.py',
#  'providers/tests/amazon/aws/waiters/test_eks.py',
#  'providers/tests/amazon/aws/waiters/test_comprehend.py',
#  'providers/tests/amazon/aws/waiters/test_ecs.py',
#  'providers/tests/amazon/aws/waiters/test_bedrock_agent.py',
#  'providers/tests/amazon/aws/waiters/test_glue.py',
#  'providers/tests/amazon/aws/waiters/test_bedrock.py',
#  'providers/tests/amazon/aws/waiters/test_dynamo.py',
#  'providers/tests/amazon/aws/waiters/test_neptune.py',
#  'providers/tests/amazon/aws/waiters/test_batch.py',
#  'providers/tests/amazon/aws/waiters/test_custom_waiters.py',
#  'providers/tests/amazon/aws/transfers/test_salesforce_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_google_api_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_glacier_to_gcs.py',
#  'providers/tests/amazon/aws/transfers/test_s3_to_sftp.py',
#  'providers/tests/amazon/aws/transfers/test_mongo_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_s3_to_redshift.py',
#  'providers/tests/amazon/aws/transfers/test_sftp_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_redshift_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_sql_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_gcs_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_s3_to_dynamodb.py',
#  'providers/tests/amazon/aws/transfers/__init__.py',
#  'providers/tests/amazon/aws/transfers/test_imap_attachment_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_http_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_hive_to_dynamodb.py',
#  'providers/tests/amazon/aws/transfers/test_s3_to_ftp.py',
#  'providers/tests/amazon/aws/transfers/test_local_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_s3_to_sql.py',
#  'providers/tests/amazon/aws/transfers/test_azure_blob_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_base.py',
#  'providers/tests/amazon/aws/transfers/test_dynamodb_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_exasol_to_s3.py',
#  'providers/tests/amazon/aws/transfers/test_ftp_to_s3.py',
#  'providers/tests/amazon/aws/system/__init__.py',
#  'providers/tests/amazon/aws/system/utils/__init__.py',
#  'providers/tests/amazon/aws/system/utils/test_helpers.py',
#  'providers/tests/amazon/aws/executors/__init__.py',
#  'providers/tests/amazon/aws/executors/utils/__init__.py',
#  'providers/tests/amazon/aws/executors/utils/test_exponential_backoff_retry.py',
#  'providers/tests/amazon/aws/executors/ecs/__init__.py',
#  'providers/tests/amazon/aws/executors/ecs/test_ecs_executor.py',
#  'providers/tests/amazon/aws/executors/batch/__init__.py',
#  'providers/tests/amazon/aws/executors/batch/test_batch_executor.py',
#  'providers/tests/amazon/aws/links/test_athena.py',
#  'providers/tests/amazon/aws/links/__init__.py',
#  'providers/tests/amazon/aws/links/test_emr.py',
#  'providers/tests/amazon/aws/links/test_base_aws.py',
#  'providers/tests/amazon/aws/links/test_step_function.py',
#  'providers/tests/amazon/aws/links/test_logs.py',
#  'providers/tests/amazon/aws/links/test_glue.py',
#  'providers/tests/amazon/aws/links/test_batch.py',
#  'providers/tests/amazon/aws/hooks/test_chime.py',
#  'providers/tests/amazon/aws/hooks/test_sagemaker.py',
#  'providers/tests/amazon/aws/hooks/test_kinesis_analytics.py',
#  'providers/tests/amazon/aws/hooks/test_kinesis.py',
#  'providers/tests/amazon/aws/hooks/test_lambda_function.py',
#  'providers/tests/amazon/aws/hooks/test_batch_waiters.py',
#  'providers/tests/amazon/aws/hooks/test_sts.py',
#  'providers/tests/amazon/aws/hooks/test_athena.py',
#  'providers/tests/amazon/aws/hooks/test_verified_permissions.py',
#  'providers/tests/amazon/aws/hooks/test_glue_databrew.py',
#  'providers/tests/amazon/aws/hooks/test_rds.py',
#  'providers/tests/amazon/aws/hooks/test_dms.py',
#  'providers/tests/amazon/aws/hooks/test_elasticache_replication_group.py',
#  'providers/tests/amazon/aws/hooks/test_dynamodb.py',
#  'providers/tests/amazon/aws/hooks/test_glue_crawler.py',
#  'providers/tests/amazon/aws/hooks/__init__.py',
#  'providers/tests/amazon/aws/hooks/test_ses.py',
#  'providers/tests/amazon/aws/hooks/test_glacier.py',
#  'providers/tests/amazon/aws/hooks/test_emr.py',
#  'providers/tests/amazon/aws/hooks/test_opensearch_serverless.py',
#  'providers/tests/amazon/aws/hooks/test_sqs.py',
#  'providers/tests/amazon/aws/hooks/test_eks.py',
#  'providers/tests/amazon/aws/hooks/test_ecr.py',
#  'providers/tests/amazon/aws/hooks/test_cloud_formation.py',
#  'providers/tests/amazon/aws/hooks/test_batch_client.py',
#  'providers/tests/amazon/aws/hooks/test_base_aws.py',
#  'providers/tests/amazon/aws/hooks/test_glue_catalog.py',
#  'providers/tests/amazon/aws/hooks/test_quicksight.py',
#  'providers/tests/amazon/aws/hooks/test_step_function.py',
#  'providers/tests/amazon/aws/hooks/test_redshift_sql.py',
#  'providers/tests/amazon/aws/hooks/test_logs.py',
#  'providers/tests/amazon/aws/hooks/test_ssm.py',
#  'providers/tests/amazon/aws/hooks/test_comprehend.py',
#  'providers/tests/amazon/aws/hooks/test_ecs.py',
#  'providers/tests/amazon/aws/hooks/test_secrets_manager.py',
#  'providers/tests/amazon/aws/hooks/test_sns.py',
#  'providers/tests/amazon/aws/hooks/test_hooks_signature.py',
#  'providers/tests/amazon/aws/hooks/test_emr_serverless.py',
#  'providers/tests/amazon/aws/hooks/test_glue.py',
#  'providers/tests/amazon/aws/hooks/test_athena_sql.py',
#  'providers/tests/amazon/aws/hooks/test_bedrock.py',
#  'providers/tests/amazon/aws/hooks/test_eventbridge.py',
#  'providers/tests/amazon/aws/hooks/test_neptune.py',
#  'providers/tests/amazon/aws/hooks/test_appflow.py',
#  'providers/tests/amazon/aws/hooks/test_ec2.py',
#  'providers/tests/amazon/aws/hooks/test_redshift_cluster.py',
#  'providers/tests/amazon/aws/hooks/test_redshift_data.py',
#  'providers/tests/amazon/aws/hooks/test_emr_containers.py',
#  'providers/tests/amazon/aws/hooks/test_datasync.py',
#  'providers/tests/amazon/aws/hooks/test_s3.py',
#  'providers/tests/amazon/aws/log/test_cloudwatch_task_handler.py',
#  'providers/tests/amazon/aws/log/__init__.py',
#  'providers/tests/amazon/aws/log/test_s3_task_handler.py',
#  'providers/tests/amazon/aws/infrastructure/__init__.py',
#  'providers/tests/amazon/aws/infrastructure/example_s3_to_redshift/outputs.tf',
#  'providers/tests/amazon/aws/infrastructure/example_s3_to_redshift/resources.tf',
#  'providers/tests/amazon/aws/infrastructure/example_s3_to_redshift/__init__.py',
#  'providers/tests/amazon/aws/infrastructure/example_s3_to_redshift/variables.tf',
#  'providers/tests/amazon/aws/fs/__init__.py',
#  'providers/tests/amazon/aws/fs/test_s3.py',
#  'providers/tests/amazon/aws/assets/__init__.py',
#  'providers/tests/amazon/aws/assets/test_s3.py',
#  'providers/tests/amazon/aws/deferrable/__init__.py',
#  'providers/tests/amazon/aws/deferrable/hooks/__init__.py',
#  'providers/tests/amazon/aws/auth_manager/test_user.py',
#  'providers/tests/amazon/aws/auth_manager/__init__.py',
#  'providers/tests/amazon/aws/auth_manager/test_aws_auth_manager.py',
#  'providers/tests/amazon/aws/auth_manager/test_constants.py',
#  'providers/tests/amazon/aws/auth_manager/cli/__init__.py',
#  'providers/tests/amazon/aws/auth_manager/cli/test_definition.py',
#  'providers/tests/amazon/aws/auth_manager/cli/test_avp_commands.py',
#  'providers/tests/amazon/aws/auth_manager/avp/__init__.py',
#  'providers/tests/amazon/aws/auth_manager/avp/test_entities.py',
#  'providers/tests/amazon/aws/auth_manager/avp/test_facade.py',
#  'providers/tests/amazon/aws/auth_manager/security_manager/__init__.py',
#  'providers/tests/amazon/aws/auth_manager/security_manager/test_aws_security_manager_override.py',
#  'providers/tests/amazon/aws/auth_manager/views/test_auth.py',
#  'providers/tests/amazon/aws/auth_manager/views/__init__.py',
#  'providers/tests/amazon/aws/notifications/test_chime.py',
#  'providers/tests/amazon/aws/notifications/__init__.py',
#  'providers/tests/amazon/aws/notifications/test_sqs.py',
#  'providers/tests/amazon/aws/notifications/test_sns.py',
#  'providers/tests/teradata/__init__.py',
#  'providers/tests/teradata/operators/__init__.py',
#  'providers/tests/teradata/operators/test_teradata.py',
#  'providers/tests/teradata/operators/test_teradata_compute_cluster.py',
#  'providers/tests/teradata/triggers/__init__.py',
#  'providers/tests/teradata/triggers/test_teradata_compute_cluster.py',
#  'providers/tests/teradata/utils/__init__.py',
#  'providers/tests/teradata/utils/test_constants.py',
#  'providers/tests/teradata/transfers/test_teradata_to_teradata.py',
#  'providers/tests/teradata/transfers/__init__.py',
#  'providers/tests/teradata/transfers/test_s3_to_teradata.py',
#  'providers/tests/teradata/transfers/test_azure_blob_to_teradata.py',
#  'providers/tests/teradata/hooks/__init__.py',
#  'providers/tests/teradata/hooks/test_teradata.py',
#  'providers/tests/grpc/__init__.py',
#  'providers/tests/grpc/operators/test_grpc.py',
#  'providers/tests/grpc/operators/__init__.py',
#  'providers/tests/grpc/hooks/test_grpc.py',
#  'providers/tests/grpc/hooks/__init__.py',
#  'providers/tests/hashicorp/__init__.py',
#  'providers/tests/hashicorp/secrets/test_vault.py',
#  'providers/tests/hashicorp/secrets/__init__.py',
#  'providers/tests/hashicorp/hooks/test_vault.py',
#  'providers/tests/hashicorp/hooks/__init__.py',
#  'providers/tests/hashicorp/_internal_client/test_vault_client.py',
#  'providers/tests/hashicorp/_internal_client/__init__.py',
#  'providers/tests/redis/__init__.py',
#  'providers/tests/redis/sensors/test_redis_key.py',
#  'providers/tests/redis/sensors/test_redis_pub_sub.py',
#  'providers/tests/redis/sensors/__init__.py',
#  'providers/tests/redis/operators/test_redis_publish.py',
#  'providers/tests/redis/operators/__init__.py',
#  'providers/tests/redis/hooks/test_redis.py',
#  'providers/tests/redis/hooks/__init__.py',
#  'providers/tests/redis/log/__init__.py',
#  'providers/tests/redis/log/test_redis_task_handler.py',
#  'providers/tests/sendgrid/__init__.py',
#  'providers/tests/sendgrid/utils/__init__.py',
#  'providers/tests/sendgrid/utils/test_emailer.py',
#  'providers/tests/dbt/__init__.py',
#  'providers/tests/dbt/cloud/__init__.py',
#  'providers/tests/dbt/cloud/sensors/__init__.py',
#  'providers/tests/dbt/cloud/sensors/test_dbt.py',
#  'providers/tests/dbt/cloud/operators/__init__.py',
#  'providers/tests/dbt/cloud/operators/test_dbt.py',
#  'providers/tests/dbt/cloud/triggers/__init__.py',
#  'providers/tests/dbt/cloud/triggers/test_dbt.py',
#  'providers/tests/dbt/cloud/test_data/job_run.json',
#  'providers/tests/dbt/cloud/test_data/__init__.py',
#  'providers/tests/dbt/cloud/test_data/run_results.json',
#  'providers/tests/dbt/cloud/test_data/manifest.json',
#  'providers/tests/dbt/cloud/test_data/catalog.json',
#  'providers/tests/dbt/cloud/utils/__init__.py',
#  'providers/tests/dbt/cloud/utils/test_openlineage.py',
#  'providers/tests/dbt/cloud/hooks/__init__.py',
#  'providers/tests/dbt/cloud/hooks/test_dbt.py',
#  'providers/tests/trino/__init__.py',
#  'providers/tests/trino/operators/__init__.py',
#  'providers/tests/trino/operators/test_trino.py',
#  'providers/tests/trino/transfers/__init__.py',
#  'providers/tests/trino/transfers/test_gcs_to_trino.py',
#  'providers/tests/trino/hooks/__init__.py',
#  'providers/tests/trino/hooks/test_trino.py',
#  'providers/tests/trino/assets/__init__.py',
#  'providers/tests/trino/assets/test_trino.py',
#  'providers/tests/integration/__init__.py',
#  'providers/tests/integration/redis/__init__.py',
#  'providers/tests/integration/redis/sensors/test_redis_key.py',
#  'providers/tests/integration/redis/sensors/test_redis_pub_sub.py',
#  'providers/tests/integration/redis/sensors/__init__.py',
#  'providers/tests/integration/redis/operators/test_redis_publish.py',
#  'providers/tests/integration/redis/operators/__init__.py',
#  'providers/tests/integration/redis/hooks/test_redis.py',
#  'providers/tests/integration/redis/hooks/__init__.py',
#  'providers/tests/integration/trino/__init__.py',
#  'providers/tests/integration/trino/hooks/__init__.py',
#  'providers/tests/integration/trino/hooks/test_trino.py',
#  'providers/tests/integration/google/__init__.py',
#  'providers/tests/integration/google/cloud/__init__.py',
#  'providers/tests/integration/google/cloud/transfers/test_bigquery_to_mssql.py',
#  'providers/tests/integration/google/cloud/transfers/test_mssql_to_gcs.py',
#  'providers/tests/integration/google/cloud/transfers/__init__.py',
#  'providers/tests/integration/google/cloud/transfers/test_trino_to_gcs.py',
#  'providers/tests/integration/microsoft/__init__.py',
#  'providers/tests/integration/microsoft/mssql/__init__.py',
#  'providers/tests/integration/microsoft/mssql/hooks/__init__.py',
#  'providers/tests/integration/microsoft/mssql/hooks/test_mssql.py',
#  'providers/tests/integration/ydb/__init__.py',
#  'providers/tests/integration/ydb/operators/__init__.py',
#  'providers/tests/integration/ydb/operators/test_ydb.py',
#  'providers/tests/integration/ydb/hooks/__init__.py',
#  'providers/tests/integration/qdrant/__init__.py',
#  'providers/tests/integration/qdrant/operators/__init__.py',
#  'providers/tests/integration/qdrant/operators/test_qdrant_ingest.py',
#  'providers/tests/integration/qdrant/hooks/__init__.py',
#  'providers/tests/integration/qdrant/hooks/test_qdrant.py',
#  'providers/tests/integration/openlineage/__init__.py',
#  'providers/tests/integration/openlineage/operators/__init__.py',
#  'providers/tests/integration/mongo/__init__.py',
#  'providers/tests/integration/mongo/sensors/__init__.py',
#  'providers/tests/integration/mongo/sensors/test_mongo.py',
#  'providers/tests/integration/apache/__init__.py',
#  'providers/tests/integration/apache/drill/__init__.py',
#  'providers/tests/integration/apache/drill/operators/__init__.py',
#  'providers/tests/integration/apache/drill/hooks/test_drill.py',
#  'providers/tests/integration/apache/drill/hooks/__init__.py',
#  'providers/tests/integration/apache/pinot/__init__.py',
#  'providers/tests/integration/apache/pinot/hooks/test_pinot.py',
#  'providers/tests/integration/apache/pinot/hooks/__init__.py',
#  'providers/tests/integration/apache/kafka/__init__.py',
#  'providers/tests/integration/apache/kafka/sensors/__init__.py',
#  'providers/tests/integration/apache/kafka/operators/test_produce.py',
#  'providers/tests/integration/apache/kafka/operators/__init__.py',
#  'providers/tests/integration/apache/kafka/operators/test_consume.py',
#  'providers/tests/integration/apache/kafka/triggers/__init__.py',
#  'providers/tests/integration/apache/kafka/triggers/test_await_message.py',
#  'providers/tests/integration/apache/kafka/hooks/test_producer.py',
#  'providers/tests/integration/apache/kafka/hooks/test_admin_client.py',
#  'providers/tests/integration/apache/kafka/hooks/__init__.py',
#  'providers/tests/integration/apache/kafka/hooks/test_consumer.py',
#  'providers/tests/integration/apache/cassandra/__init__.py',
#  'providers/tests/integration/apache/cassandra/hooks/__init__.py',
#  'providers/tests/integration/apache/cassandra/hooks/test_cassandra.py',
#  'providers/tests/integration/apache/hive/__init__.py',
#  'providers/tests/integration/apache/hive/transfers/test_mssql_to_hive.py',
#  'providers/tests/integration/apache/hive/transfers/__init__.py',
#  'providers/tests/opensearch/conftest.py',
#  'providers/tests/opensearch/__init__.py',
#  'providers/tests/opensearch/operators/__init__.py',
#  'providers/tests/opensearch/operators/test_opensearch.py',
#  'providers/tests/opensearch/hooks/__init__.py',
#  'providers/tests/opensearch/hooks/test_opensearch.py',
#  'providers/tests/opensearch/log/__init__.py',
#  'providers/tests/opensearch/log/test_os_response.py',
#  'providers/tests/opensearch/log/test_os_task_handler.py',
#  'providers/tests/opensearch/log/test_os_json_formatter.py',
#  'providers/tests/google/test_go_module.py',
#  'providers/tests/google/__init__.py',
#  'providers/tests/google/ads/__init__.py',
#  'providers/tests/google/ads/operators/test_ads.py',
#  'providers/tests/google/ads/operators/__init__.py',
#  'providers/tests/google/ads/transfers/test_ads_to_gcs.py',
#  'providers/tests/google/ads/transfers/__init__.py',
#  'providers/tests/google/ads/hooks/test_ads.py',
#  'providers/tests/google/ads/hooks/__init__.py',
#  'providers/tests/google/leveldb/__init__.py',
#  'providers/tests/google/leveldb/operators/__init__.py',
#  'providers/tests/google/leveldb/operators/test_leveldb.py',
#  'providers/tests/google/leveldb/hooks/__init__.py',
#  'providers/tests/google/leveldb/hooks/test_leveldb.py',
#  'providers/tests/google/marketing_platform/__init__.py',
#  'providers/tests/google/marketing_platform/sensors/test_display_video.py',
#  'providers/tests/google/marketing_platform/sensors/test_campaign_manager.py',
#  'providers/tests/google/marketing_platform/sensors/__init__.py',
#  'providers/tests/google/marketing_platform/operators/test_display_video.py',
#  'providers/tests/google/marketing_platform/operators/test_campaign_manager.py',
#  'providers/tests/google/marketing_platform/operators/__init__.py',
#  'providers/tests/google/marketing_platform/operators/test_analytics_admin.py',
#  'providers/tests/google/marketing_platform/operators/test_display_video_system.py',
#  'providers/tests/google/marketing_platform/operators/test_search_ads.py',
#  'providers/tests/google/marketing_platform/links/__init__.py',
#  'providers/tests/google/marketing_platform/links/test_analytics_admin.py',
#  'providers/tests/google/marketing_platform/hooks/test_display_video.py',
#  'providers/tests/google/marketing_platform/hooks/test_campaign_manager.py',
#  'providers/tests/google/marketing_platform/hooks/__init__.py',
#  'providers/tests/google/marketing_platform/hooks/test_analytics_admin.py',
#  'providers/tests/google/marketing_platform/hooks/test_search_ads.py',
#  'providers/tests/google/common/__init__.py',
#  'providers/tests/google/common/test_deprecated.py',
#  'providers/tests/google/common/auth_backend/test_google_openid.py',
#  'providers/tests/google/common/auth_backend/__init__.py',
#  'providers/tests/google/common/utils/__init__.py',
#  'providers/tests/google/common/utils/test_id_token_credentials.py',
#  'providers/tests/google/common/hooks/test_base_google.py',
#  'providers/tests/google/common/hooks/__init__.py',
#  'providers/tests/google/common/hooks/test_discovery_api.py',
#  'providers/tests/google/firebase/__init__.py',
#  'providers/tests/google/firebase/operators/test_firestore.py',
#  'providers/tests/google/firebase/operators/__init__.py',
#  'providers/tests/google/firebase/hooks/test_firestore.py',
#  'providers/tests/google/firebase/hooks/__init__.py',
#  'providers/tests/google/cloud/__init__.py',
#  'providers/tests/google/cloud/sensors/test_workflows.py',
#  'providers/tests/google/cloud/sensors/test_datafusion.py',
#  'providers/tests/google/cloud/sensors/test_dataproc_metastore.py',
#  'providers/tests/google/cloud/sensors/test_bigquery_dts.py',
#  'providers/tests/google/cloud/sensors/test_looker.py',
#  'providers/tests/google/cloud/sensors/test_bigquery.py',
#  'providers/tests/google/cloud/sensors/test_pubsub.py',
#  'providers/tests/google/cloud/sensors/test_dataform.py',
#  'providers/tests/google/cloud/sensors/test_dataprep.py',
#  'providers/tests/google/cloud/sensors/__init__.py',
#  'providers/tests/google/cloud/sensors/test_gcs.py',
#  'providers/tests/google/cloud/sensors/test_dataplex.py',
#  'providers/tests/google/cloud/sensors/test_dataflow.py',
#  'providers/tests/google/cloud/sensors/test_tasks.py',
#  'providers/tests/google/cloud/sensors/test_cloud_composer.py',
#  'providers/tests/google/cloud/sensors/test_dataproc.py',
#  'providers/tests/google/cloud/sensors/test_bigtable.py',
#  'providers/tests/google/cloud/sensors/test_cloud_storage_transfer_service.py',
#  'providers/tests/google/cloud/operators/test_cloud_run.py',
#  'providers/tests/google/cloud/operators/test_workflows.py',
#  'providers/tests/google/cloud/operators/test_datafusion.py',
#  'providers/tests/google/cloud/operators/test_dataproc_metastore.py',
#  'providers/tests/google/cloud/operators/test_vertex_ai.py',
#  'providers/tests/google/cloud/operators/test_bigquery_dts.py',
#  'providers/tests/google/cloud/operators/test_looker.py',
#  'providers/tests/google/cloud/operators/test_bigquery.py',
#  'providers/tests/google/cloud/operators/test_pubsub.py',
#  'providers/tests/google/cloud/operators/test_datastore_system.py',
#  'providers/tests/google/cloud/operators/test_datapipeline.py',
#  'providers/tests/google/cloud/operators/test_datacatalog.py',
#  'providers/tests/google/cloud/operators/test_text_to_speech.py',
#  'providers/tests/google/cloud/operators/test_datastore.py',
#  'providers/tests/google/cloud/operators/test_automl.py',
#  'providers/tests/google/cloud/operators/test_dataform.py',
#  'providers/tests/google/cloud/operators/test_dataprep.py',
#  'providers/tests/google/cloud/operators/__init__.py',
#  'providers/tests/google/cloud/operators/test_gcs.py',
#  'providers/tests/google/cloud/operators/test_dataplex.py',
#  'providers/tests/google/cloud/operators/test_natural_language.py',
#  'providers/tests/google/cloud/operators/test_kubernetes_engine.py',
#  'providers/tests/google/cloud/operators/test_mlengine.py',
#  'providers/tests/google/cloud/operators/test_dlp.py',
#  'providers/tests/google/cloud/operators/test_cloud_build.py',
#  'providers/tests/google/cloud/operators/test_spanner.py',
#  'providers/tests/google/cloud/operators/test_dataflow.py',
#  'providers/tests/google/cloud/operators/test_stackdriver.py',
#  'providers/tests/google/cloud/operators/test_translate.py',
#  'providers/tests/google/cloud/operators/test_tasks.py',
#  'providers/tests/google/cloud/operators/test_speech_to_text.py',
#  'providers/tests/google/cloud/operators/test_functions.py',
#  'providers/tests/google/cloud/operators/test_vision.py',
#  'providers/tests/google/cloud/operators/test_cloud_composer.py',
#  'providers/tests/google/cloud/operators/test_cloud_base.py',
#  'providers/tests/google/cloud/operators/test_life_sciences.py',
#  'providers/tests/google/cloud/operators/test_cloud_batch.py',
#  'providers/tests/google/cloud/operators/test_dataprep_system.py',
#  'providers/tests/google/cloud/operators/test_cloud_memorystore.py',
#  'providers/tests/google/cloud/operators/test_dataproc.py',
#  'providers/tests/google/cloud/operators/test_cloud_sql.py',
#  'providers/tests/google/cloud/operators/test_compute.py',
#  'providers/tests/google/cloud/operators/test_bigtable.py',
#  'providers/tests/google/cloud/operators/test_cloud_storage_transfer_service.py',
#  'providers/tests/google/cloud/operators/test_translate_speech.py',
#  'providers/tests/google/cloud/operators/test_video_intelligence.py',
#  'providers/tests/google/cloud/operators/source/__init__.py',
#  'providers/tests/google/cloud/operators/source/source_prefix/__init__.py',
#  'providers/tests/google/cloud/operators/vertex_ai/test_generative_model.py',
#  'providers/tests/google/cloud/operators/vertex_ai/__init__.py',
#  'providers/tests/google/cloud/triggers/test_cloud_run.py',
#  'providers/tests/google/cloud/triggers/test_datafusion.py',
#  'providers/tests/google/cloud/triggers/test_vertex_ai.py',
#  'providers/tests/google/cloud/triggers/test_bigquery_dts.py',
#  'providers/tests/google/cloud/triggers/test_bigquery.py',
#  'providers/tests/google/cloud/triggers/test_pubsub.py',
#  'providers/tests/google/cloud/triggers/__init__.py',
#  'providers/tests/google/cloud/triggers/test_gcs.py',
#  'providers/tests/google/cloud/triggers/test_dataplex.py',
#  'providers/tests/google/cloud/triggers/test_kubernetes_engine.py',
#  'providers/tests/google/cloud/triggers/test_mlengine.py',
#  'providers/tests/google/cloud/triggers/test_cloud_build.py',
#  'providers/tests/google/cloud/triggers/test_dataflow.py',
#  'providers/tests/google/cloud/triggers/test_cloud_composer.py',
#  'providers/tests/google/cloud/triggers/test_cloud_batch.py',
#  'providers/tests/google/cloud/triggers/test_dataproc.py',
#  'providers/tests/google/cloud/triggers/test_cloud_sql.py',
#  'providers/tests/google/cloud/triggers/test_cloud_storage_transfer_service.py',
#  'providers/tests/google/cloud/secrets/test_secret_manager.py',
#  'providers/tests/google/cloud/secrets/__init__.py',
#  'providers/tests/google/cloud/secrets/test_secret_manager_system.py',
#  'providers/tests/google/cloud/utils/out_table_details.json',
#  'providers/tests/google/cloud/utils/test_credentials_provider.py',
#  'providers/tests/google/cloud/utils/test_datafusion.py',
#  'providers/tests/google/cloud/utils/table_details.json',
#  'providers/tests/google/cloud/utils/test_mlengine_operator_utils.py',
#  'providers/tests/google/cloud/utils/__init__.py',
#  'providers/tests/google/cloud/utils/test_mlengine_prediction_summary.py',
#  'providers/tests/google/cloud/utils/gcp_authenticator.py',
#  'providers/tests/google/cloud/utils/test_field_validator.py',
#  'providers/tests/google/cloud/utils/test_external_token_supplier.py',
#  'providers/tests/google/cloud/utils/script_job_details.json',
#  'providers/tests/google/cloud/utils/test_field_sanitizer.py',
#  'providers/tests/google/cloud/utils/test_helpers.py',
#  'providers/tests/google/cloud/utils/job_details.json',
#  'providers/tests/google/cloud/utils/airflow_util.py',
#  'providers/tests/google/cloud/utils/test_dataproc.py',
#  'providers/tests/google/cloud/utils/base_gcp_mock.py',
#  'providers/tests/google/cloud/transfers/test_postgres_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_gcs_to_local.py',
#  'providers/tests/google/cloud/transfers/test_gdrive_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_gdrive_to_local.py',
#  'providers/tests/google/cloud/transfers/test_salesforce_to_gcs_system.py',
#  'providers/tests/google/cloud/transfers/test_bigquery_to_mssql.py',
#  'providers/tests/google/cloud/transfers/test_gcs_to_sftp.py',
#  'providers/tests/google/cloud/transfers/test_mssql_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_adls_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_mysql_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_calendar_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_s3_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_bigquery_to_bigquery.py',
#  'providers/tests/google/cloud/transfers/test_facebook_ads_to_gcs_system.py',
#  'providers/tests/google/cloud/transfers/__init__.py',
#  'providers/tests/google/cloud/transfers/test_salesforce_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_sql_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_sheets_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_gcs_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_sftp_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_azure_blob_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_oracle_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_local_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_cassandra_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_gcs_to_bigquery.py',
#  'providers/tests/google/cloud/transfers/test_bigquery_to_postgres.py',
#  'providers/tests/google/cloud/transfers/test_azure_fileshare_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_bigquery_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_bigquery_to_mysql.py',
#  'providers/tests/google/cloud/transfers/test_trino_to_gcs.py',
#  'providers/tests/google/cloud/transfers/test_facebook_ads_to_gcs.py',
#  'providers/tests/google/cloud/links/__init__.py',
#  'providers/tests/google/cloud/links/test_translate.py',
#  'providers/tests/google/cloud/hooks/test_cloud_run.py',
#  'providers/tests/google/cloud/hooks/test_workflows.py',
#  'providers/tests/google/cloud/hooks/test_os_login.py',
#  'providers/tests/google/cloud/hooks/test_datafusion.py',
#  'providers/tests/google/cloud/hooks/test_dataproc_metastore.py',
#  'providers/tests/google/cloud/hooks/test_bigquery_dts.py',
#  'providers/tests/google/cloud/hooks/test_bigquery_system.py',
#  'providers/tests/google/cloud/hooks/test_looker.py',
#  'providers/tests/google/cloud/hooks/test_bigquery.py',
#  'providers/tests/google/cloud/hooks/test_pubsub.py',
#  'providers/tests/google/cloud/hooks/test_secret_manager.py',
#  'providers/tests/google/cloud/hooks/test_datapipeline.py',
#  'providers/tests/google/cloud/hooks/test_datacatalog.py',
#  'providers/tests/google/cloud/hooks/test_text_to_speech.py',
#  'providers/tests/google/cloud/hooks/test_kms_system.py',
#  'providers/tests/google/cloud/hooks/test_datastore.py',
#  'providers/tests/google/cloud/hooks/test_automl.py',
#  'providers/tests/google/cloud/hooks/test_dataform.py',
#  'providers/tests/google/cloud/hooks/test_dataprep.py',
#  'providers/tests/google/cloud/hooks/__init__.py',
#  'providers/tests/google/cloud/hooks/test_gcs.py',
#  'providers/tests/google/cloud/hooks/test_dataplex.py',
#  'providers/tests/google/cloud/hooks/test_kms.py',
#  'providers/tests/google/cloud/hooks/test_natural_language.py',
#  'providers/tests/google/cloud/hooks/test_kubernetes_engine.py',
#  'providers/tests/google/cloud/hooks/test_mlengine.py',
#  'providers/tests/google/cloud/hooks/test_dlp.py',
#  'providers/tests/google/cloud/hooks/test_compute_ssh.py',
#  'providers/tests/google/cloud/hooks/test_cloud_build.py',
#  'providers/tests/google/cloud/hooks/test_spanner.py',
#  'providers/tests/google/cloud/hooks/test_gdm.py',
#  'providers/tests/google/cloud/hooks/test_dataflow.py',
#  'providers/tests/google/cloud/hooks/test_stackdriver.py',
#  'providers/tests/google/cloud/hooks/test_translate.py',
#  'providers/tests/google/cloud/hooks/test_tasks.py',
#  'providers/tests/google/cloud/hooks/test_speech_to_text.py',
#  'providers/tests/google/cloud/hooks/test_functions.py',
#  'providers/tests/google/cloud/hooks/test_vision.py',
#  'providers/tests/google/cloud/hooks/test_cloud_composer.py',
#  'providers/tests/google/cloud/hooks/test_secret_manager_system.py',
#  'providers/tests/google/cloud/hooks/test_life_sciences.py',
#  'providers/tests/google/cloud/hooks/test_cloud_batch.py',
#  'providers/tests/google/cloud/hooks/test_cloud_memorystore.py',
#  'providers/tests/google/cloud/hooks/test_dataproc.py',
#  'providers/tests/google/cloud/hooks/test_cloud_sql.py',
#  'providers/tests/google/cloud/hooks/test_compute.py',
#  'providers/tests/google/cloud/hooks/test_bigtable.py',
#  'providers/tests/google/cloud/hooks/test_cloud_storage_transfer_service.py',
#  'providers/tests/google/cloud/hooks/test_cloud_storage_transfer_service_async.py',
#  'providers/tests/google/cloud/hooks/test_video_intelligence.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_generative_model.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_pipeline_job.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_custom_job.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_batch_prediction_job.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_endpoint_service.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_prediction_service.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/__init__.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_auto_ml.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_dataset.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_hyperparameter_tuning_job.py',
#  'providers/tests/google/cloud/hooks/vertex_ai/test_model_service.py',
#  'providers/tests/google/cloud/openlineage/test_utils.py',
#  'providers/tests/google/cloud/openlineage/__init__.py',
#  ...]

# %%
from pinecone import Pinecone, ServerlessSpec
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

# %%
PINECONE_API_KEY = ''
OPENAI_API_KEY = ''

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large", api_key=OPENAI_API_KEY)
pinecone_api_key = PINECONE_API_KEY
pc = Pinecone(api_key=pinecone_api_key)

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(
    chunk_size = 10000,
    chunk_overlap  = 200
)
text = text_splitter.create_documents([code_text])
# Out:
# Created a chunk of size 56938, which is longer than the specified 10000
# Created a chunk of size 31385, which is longer than the specified 10000
# Created a chunk of size 44616, which is longer than the specified 10000
# Created a chunk of size 25913, which is longer than the specified 10000
# Created a chunk of size 11506, which is longer than the specified 10000
# Created a chunk of size 61904, which is longer than the specified 10000
# Created a chunk of size 33029, which is longer than the specified 10000
# Created a chunk of size 312098, which is longer than the specified 10000
# Created a chunk of size 18436, which is longer than the specified 10000
# Created a chunk of size 12325, which is longer than the specified 10000
# Created a chunk of size 17848, which is longer than the specified 10000
# Created a chunk of size 303798, which is longer than the specified 10000
# Created a chunk of size 11173, which is longer than the specified 10000
# Created a chunk of size 15257, which is longer than the specified 10000
# Created a chunk of size 13854, which is longer than the specified 10000
# Created a chunk of size 11464, which is longer than the specified 10000
# Created a chunk of size 10177, which is longer than the specified 10000
# Created a chunk of size 11229, which is longer than the specified 10000
# Created a chunk of size 625484, which is longer than the specified 10000
# Created a chunk of size 11327, which is longer than the specified 10000
# Created a chunk of size 12132, which is longer than the specified 10000
# Created a chunk of size 12499, which is longer than the specified 10000
# Created a chunk of size 16409, which is longer than the specified 10000
# Created a chunk of size 14396, which is longer than the specified 10000
# Created a chunk of size 14961, which is longer than the specified 10000
# Created a chunk of size 22063, which is longer than the specified 10000
# Created a chunk of size 10193, which is longer than the specified 10000
# Created a chunk of size 17275, which is longer than the specified 10000
# Created a chunk of size 11413, which is longer than the specified 10000
# Created a chunk of size 10333, which is longer than the specified 10000
# Created a chunk of size 10589, which is longer than the specified 10000
# Created a chunk of size 10158, which is longer than the specified 10000
# Created a chunk of size 10687, which is longer than the specified 10000
# Created a chunk of size 10163, which is longer than the specified 10000
# Created a chunk of size 10122, which is longer than the specified 10000
# Created a chunk of size 14039, which is longer than the specified 10000
# Created a chunk of size 13616, which is longer than the specified 10000
# Created a chunk of size 10753, which is longer than the specified 10000
# Created a chunk of size 11728, which is longer than the specified 10000
# Created a chunk of size 11187, which is longer than the specified 10000
# Created a chunk of size 11836, which is longer than the specified 10000
# Created a chunk of size 38405, which is longer than the specified 10000
# Created a chunk of size 15458, which is longer than the specified 10000
# Created a chunk of size 17500, which is longer than the specified 10000
# Created a chunk of size 11442, which is longer than the specified 10000
# Created a chunk of size 10509, which is longer than the specified 10000
# Created a chunk of size 66866, which is longer than the specified 10000
# Created a chunk of size 20373, which is longer than the specified 10000
# Created a chunk of size 37177, which is longer than the specified 10000
# Created a chunk of size 47008, which is longer than the specified 10000
# Created a chunk of size 26013, which is longer than the specified 10000
# Created a chunk of size 39557, which is longer than the specified 10000
# Created a chunk of size 13771, which is longer than the specified 10000
# Created a chunk of size 14634, which is longer than the specified 10000
# Created a chunk of size 14227, which is longer than the specified 10000
# Created a chunk of size 10351, which is longer than the specified 10000
# Created a chunk of size 27235, which is longer than the specified 10000
# Created a chunk of size 40368, which is longer than the specified 10000
# Created a chunk of size 76249, which is longer than the specified 10000
# Created a chunk of size 40439, which is longer than the specified 10000
# Created a chunk of size 53145, which is longer than the specified 10000
# Created a chunk of size 40489, which is longer than the specified 10000
# Created a chunk of size 11145, which is longer than the specified 10000
# Created a chunk of size 15552, which is longer than the specified 10000
# Created a chunk of size 28945, which is longer than the specified 10000
# Created a chunk of size 110138, which is longer than the specified 10000
# Created a chunk of size 10989, which is longer than the specified 10000
# Created a chunk of size 10135, which is longer than the specified 10000
# Created a chunk of size 24958, which is longer than the specified 10000
# Created a chunk of size 26561, which is longer than the specified 10000
# Created a chunk of size 65458, which is longer than the specified 10000
# Created a chunk of size 78292, which is longer than the specified 10000
# Created a chunk of size 12229, which is longer than the specified 10000
# Created a chunk of size 18731, which is longer than the specified 10000
# Created a chunk of size 10488, which is longer than the specified 10000
# Created a chunk of size 36764, which is longer than the specified 10000
# Created a chunk of size 16613, which is longer than the specified 10000
# Created a chunk of size 22397, which is longer than the specified 10000
# Created a chunk of size 17218, which is longer than the specified 10000
# Created a chunk of size 12710, which is longer than the specified 10000
# Created a chunk of size 25457, which is longer than the specified 10000
# Created a chunk of size 11805, which is longer than the specified 10000
# Created a chunk of size 23044, which is longer than the specified 10000
# Created a chunk of size 41010, which is longer than the specified 10000
# Created a chunk of size 14110, which is longer than the specified 10000
# Created a chunk of size 11729, which is longer than the specified 10000
# Created a chunk of size 17220, which is longer than the specified 10000
# Created a chunk of size 10079, which is longer than the specified 10000
# Created a chunk of size 10455, which is longer than the specified 10000
# Created a chunk of size 616543, which is longer than the specified 10000

# %%
text1 = [chunk for chunk in text if len(chunk.page_content) <= 10000]

# %%
len(text1)
# Out:
# 5877

# %%
pc.create_index(
                name='airflow-github',
                dimension=3072,
                metric="cosine",
                spec=ServerlessSpec(cloud="aws", region="us-east-1"),
            )

# %%
index_name = 'airflow-github'

# %%
index = pc.Index(index_name)

# %%
vector_store = PineconeVectorStore(index=index, embedding=embeddings)

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 3})
context = retriever.invoke("Give me code to setup Airflow")

# %%
import time
from typing import List
from langchain.schema import Document
from langchain.vectorstores import VectorStore
from openai import RateLimitError
import backoff

@backoff.on_exception(backoff.expo, RateLimitError, max_tries=8)
def add_documents_with_backoff(vector_store: VectorStore, documents: List[Document], batch_size: int = 100) -> List[str]:
    return vector_store.add_documents(documents[:batch_size])

# %%
def add_documents_to_vectorstore(vector_store: VectorStore, documents: List[Document], batch_size: int = 50) -> List[str]:
    all_ids = []
    for i in range(0, len(documents), batch_size):
        batch = documents[i:i+batch_size]
        try:
            ids = add_documents_with_backoff(vector_store, batch, batch_size)
            all_ids.extend(ids)
            time.sleep(60)
        except Exception as e:
            print(f"Error adding batch to vector store: {e}")
    return all_ids

# %%
ids = add_documents_to_vectorstore(vector_store, text1, batch_size=50)

# %%
from git import Repo
import os

repo_url = ""
clone_directory = "test-github-push"

new_branch_name = "feature/new-branch"

# %%
repo = Repo.clone_from(repo_url, clone_directory)

# %%
repo.git.checkout('-b', new_branch_name)
# Out:
# ''

# %%
file_path = os.path.join(clone_directory, "example.txt")

# %%
with open(file_path, "w") as file:
    file.write("Testing New file push to Git!\n")

# %%
repo.index.add(["/Users/ramkumarrp/test-github-push/example.txt"])
# Out:
# [(100644, 790761d8c903a93052b9cda639efb5bc4259a102, 0, example.txt)]

# %%
commit_message = "Checking commit"
repo.index.commit(commit_message)
# Out:
# <git.Commit "b1dfe01ea7c417b8fe6570edac5b18e62ad5700b">

# %%
origin = repo.remote(name='origin')
origin.push(refspec=f"{new_branch_name}:{new_branch_name}")
